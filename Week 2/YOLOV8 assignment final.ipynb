# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.2/800.2 kB 8.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/car
# Out:
# /content/drive/MyDrive/car

# %%
# !ls
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# %cd /content/drive/MyDrive/car
# !yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=20 plots=True
# Out:
# /content/drive/MyDrive/car
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/car/runs/detect/train2/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,849,024 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/car/valid/labels.cache... 160 images, 1 backgrounds, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:08<00:00,  1.15it/s]
#                    all        160       1055      0.775      0.733      0.767      0.588
#                   boot         35         39       0.87       0.59      0.714      0.585
#                    car        142        145      0.928      0.966      0.938      0.871
#                   door         50         52        0.9      0.673      0.852      0.627
#           front_bumper         30         30      0.643       0.66      0.614      0.438
#            front_grill         49         51      0.651      0.667      0.676      0.565
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/car/runs/detect/train2/weights/best.pt source=/content/drive/MyDrive/car/test/images
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,849,024 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/22 /content/drive/MyDrive/car/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg: 640x640 1 front_grill, 1 license_plate, 37.1ms
# image 2/22 /content/drive/MyDrive/car/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg: 640x640 2 cars, 1 license_plate, 37.2ms
# image 3/22 /content/drive/MyDrive/car/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg: 640x640 2 cars, 3 license_plates, 37.2ms
# image 4/22 /content/drive/MyDrive/car/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg: 640x640 2 headlamps, 1 hood, 1 license_plate, 37.1ms
# image 5/22 /content/drive/MyDrive/car/test/images/Cars306_png.rf.dd001ad2f0e6c305bf5bd3d704eebd75.jpg: 640x640 1 car, 1 front_grill, 1 front_windshield, 2 headlamps, 1 license_plate, 1 sideview_mirror, 33.2ms
# ...
